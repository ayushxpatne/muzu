# %%
import csv
filename = 'transactions.csv'
import pandas as pd
def read_csv_2(filename):
    x =  pd.read_csv(filename).to_dict('records')
    return x


read_csv_2(filename)
# Out:
# [{'title': 'Transaction1 on Food',
#   'amount': 157.26,
#   'date': 'Thu, Feb 01, 2024',
#   'category': 'Food'},
#  {'title': 'Transaction2 on Entertainment',
#   'amount': 185.03,
#   'date': 'Thu, Feb 01, 2024',
#   'category': 'Entertainment'},
#  {'title': 'Transaction3 on Fitness',
#   'amount': 130.97,
#   'date': 'Thu, Feb 01, 2024',
#   'category': 'Fitness'},
#  {'title': 'Transaction4 on Fitness',
#   'amount': 75.79,
#   'date': 'Thu, Feb 01, 2024',
#   'category': 'Fitness'},
#  {'title': 'Transaction5 on Entertainment',
#   'amount': 19.74,
#   'date': 'Thu, Feb 01, 2024',
#   'category': 'Entertainment'},
#  {'title': 'Transaction6 on Fitness',
#   'amount': 107.42,
#   'date': 'Thu, Feb 01, 2024',
#   'category': 'Fitness'},
#  {'title': 'Transaction7 on Shopping',
#   'amount': 53.99,
#   'date': 'Thu, Feb 01, 2024',
#   'category': 'Shopping'},
#  {'title': 'Transaction8 on Transportation',
#   'amount': 139.87,
#   'date': 'Thu, Feb 01, 2024',
# ...
